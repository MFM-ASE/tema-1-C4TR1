# %%
! pip install yfinance
import warnings
warnings.filterwarnings('ignore')

# %%
! pip install pathlib

# %%
! pip install ruamel-yaml

# %%
import yfinance as yf
import numpy as np
import pandas as pd

#define the ticker symbol
tickerSymbol = 'CL=F'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
df = tickerData.history(period='1d', start='2022-1-1', end='2022-10-16')

#see your data
df
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2022-01-03 00:00:00-05:00  75.690002  76.459999  74.269997  76.080002  317628
# 2022-01-04 00:00:00-05:00  76.019997  77.639999  75.699997  76.989998  372848
# 2022-01-05 00:00:00-05:00  77.180000  78.580002  76.510002  77.849998  397898
# 2022-01-06 00:00:00-05:00  77.239998  80.239998  76.730003  79.459999  476665
# 2022-01-07 00:00:00-05:00  79.620003  80.470001  78.519997  78.900002  414434
# ...                              ...        ...        ...        ...     ...
# 2022-10-10 00:00:00-04:00  93.480003  93.639999  90.540001  91.129997  289508
# 2022-10-11 00:00:00-04:00  91.139999  91.349998  87.910004  89.349998  333158
# 2022-10-12 00:00:00-04:00  88.669998  90.070000  86.279999  87.269997  332271
# 2022-10-13 00:00:00-04:00  87.080002  89.660004  85.559998  89.110001  298032
# 2022-10-14 00:00:00-04:00  89.269997  89.730003  85.199997  85.610001  237026
#
# ...

# %%
#define the ticker symbol
tickerSymbol2 = 'GC=F'

#get data on this ticker
tickerData2 = yf.Ticker(tickerSymbol2)

#get the historical prices for this ticker
df2 = tickerData2.history(period='1d', start='2022-1-1', end='2022-10-16')

#see your data
df2

df2.rename(columns = {'Open':'Open2', 'High':'High2', 'Low':'Low2', 'Close':'Close2', 'Volume':'Volume2', 'Dividends':'Dividends2', 'Stock Splits':'Stock Splits2'}, inplace = True)
df2
# Out:
#                                  Open2        High2         Low2       Close2  \
# Date
# 2022-01-03 00:00:00-05:00  1830.099976  1830.099976  1798.800049  1799.400024
# 2022-01-04 00:00:00-05:00  1800.500000  1815.300049  1800.000000  1814.000000
# 2022-01-05 00:00:00-05:00  1813.099976  1824.599976  1813.099976  1824.599976
# 2022-01-06 00:00:00-05:00  1787.099976  1791.300049  1787.099976  1788.699951
# 2022-01-07 00:00:00-05:00  1791.800049  1797.000000  1784.400024  1797.000000
# ...                                ...          ...          ...          ...
# 2022-10-10 00:00:00-04:00  1693.400024  1693.400024  1667.000000  1667.300049
# 2022-10-11 00:00:00-04:00  1661.800049  1678.699951  1661.000000  1678.699951
# 2022-10-12 00:00:00-04:00  1668.000000  1672.699951  1668.000000  1670.300049
# 2022-10-13 00:00:00-04:00  1675.199951  1675.300049  1641.500000  1670.000000
# 2022-10-14 00:00:00-04:00  1665.300049  1667.000000  1640.000000  1641.699951
#
# ...

# %%
dataframe = pd.concat([df,df2], axis=1)
dataframe
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2022-01-03 00:00:00-05:00  75.690002  76.459999  74.269997  76.080002  317628
# 2022-01-04 00:00:00-05:00  76.019997  77.639999  75.699997  76.989998  372848
# 2022-01-05 00:00:00-05:00  77.180000  78.580002  76.510002  77.849998  397898
# 2022-01-06 00:00:00-05:00  77.239998  80.239998  76.730003  79.459999  476665
# 2022-01-07 00:00:00-05:00  79.620003  80.470001  78.519997  78.900002  414434
# ...                              ...        ...        ...        ...     ...
# 2022-10-10 00:00:00-04:00  93.480003  93.639999  90.540001  91.129997  289508
# 2022-10-11 00:00:00-04:00  91.139999  91.349998  87.910004  89.349998  333158
# 2022-10-12 00:00:00-04:00  88.669998  90.070000  86.279999  87.269997  332271
# 2022-10-13 00:00:00-04:00  87.080002  89.660004  85.559998  89.110001  298032
# 2022-10-14 00:00:00-04:00  89.269997  89.730003  85.199997  85.610001  237026
#
# ...

# %%
close = dataframe[["Close", "Close2"]]
print(close)

simple_return = close.pct_change()
print(simple_return)

log_return = np.log(1+simple_return)
print(log_return)
# Out:
#                                Close       Close2
# Date
# 2022-01-03 00:00:00-05:00  76.080002  1799.400024
# 2022-01-04 00:00:00-05:00  76.989998  1814.000000
# 2022-01-05 00:00:00-05:00  77.849998  1824.599976
# 2022-01-06 00:00:00-05:00  79.459999  1788.699951
# 2022-01-07 00:00:00-05:00  78.900002  1797.000000
# ...                              ...          ...
# 2022-10-10 00:00:00-04:00  91.129997  1667.300049
# 2022-10-11 00:00:00-04:00  89.349998  1678.699951
# 2022-10-12 00:00:00-04:00  87.269997  1670.300049
# 2022-10-13 00:00:00-04:00  89.110001  1670.000000
# 2022-10-14 00:00:00-04:00  85.610001  1641.699951
#
# [199 rows x 2 columns]
#                               Close    Close2
# Date
# 2022-01-03 00:00:00-05:00       NaN       NaN
# 2022-01-04 00:00:00-05:00  0.011961  0.008114
# 2022-01-05 00:00:00-05:00  0.011170  0.005843
# 2022-01-06 00:00:00-05:00  0.020681 -0.019676
# 2022-01-07 00:00:00-05:00 -0.007048  0.004640
# ...

# %%
import matplotlib.pyplot as plt  
# %matplotlib inline
# %pylab inline

pylab.rcParams['figure.figsize'] = (15, 9)  

#apple["Adj. Close"].plot(grid = False) 


print(log_return["Close"].plot())
print(log_return["Close2"].plot())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# AxesSubplot(0.125,0.2;0.775x0.68)
# AxesSubplot(0.125,0.2;0.775x0.68)

# %%
import seaborn as sns

# histogram
sns.distplot(log_return["Close"], kde=False, norm_hist=True,label='Log-returns') 
sns.distplot(simple_return["Close"], kde=False, norm_hist=True, label='Simple returns')  

legend(loc='upper left');

# plt.tight_layout()
# plt.savefig('images/ch1_im10.png')
plt.show()

# %%
import seaborn as sns

# histogram
sns.distplot(log_return["Close2"], kde=False, norm_hist=True,label='Log-returns') 
sns.distplot(simple_return["Close2"], kde=False, norm_hist=True, label='Simple returns')  

legend(loc='upper left');

# plt.tight_layout()
# plt.savefig('images/ch1_im10.png')
plt.show()

# %%
import seaborn as sns

# histogram
sns.distplot(log_return["Close"], kde=False, norm_hist=True,label='Log-returns') 
sns.distplot(simple_return["Close"], kde=False, norm_hist=True, label='Simple returns')  

legend(loc='upper left');

# plt.tight_layout()
# plt.savefig('images/ch1_im10.png')
plt.show()
